# %%
### Import libraries

# %%
import os
import csv
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
from config import username, password

# %%
## Import CVS file

# %%
file = 'data/clean_data_all.csv'

# %%
music_df = pd.read_csv(file, encoding = "UTF-8")
music_df['Genre'].fillna('', inplace=True)
music_df.head(2)
# Out:
#    Decade  Year                            Artist  \
# 0    1940  1940  Various Artists, Igor Stravinsky
# 1    1970  1977                         Fela Kuti
#
#                                                 Song  \
# 0  A propos of Le Sacre - Commentary by Igor Stra...
# 1                                    Opposite People
#
#                                   Genre  Duration_ms  \
# 0                                             999827
# 1  afrobeat, afropop, funk, soul, world       998280
#
#                                           ArtistSong  Valence  Acousticness  \
# 0  Various Artists, Igor Stravinsky - A propos of...    0.405          0.35
# 1                        Fela Kuti - Opposite People    0.904          0.11
#
#    Danceability  ...  Explicit  Instrumentalness  Key  Liveness  Loudness  \
# 0         0.635  ...         0            0.0000    1     0.383   -30.467
# 1         0.668  ...         0            0.0543    5     0.123    -5.167
#
#    Mode  Popularity  Speechiness    Tempo                      ID
# 0     0           0        0.930   85.650  431ryeJJoLFxBX1iSJFMde
# 1     0          25        0.177  117.973  2nsQdjrZesTsFqVpYNBpUm
#
# [2 rows x 21 columns]

# %%
## Connect to local DataBase

# %%
file = 'data/clean_data_all.csv'

# %%
music_df = pd.read_csv(file)

# %%
## Create Engine

# %%
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@localhost:5432')
connection = engine.connect()

# %%
## Create New DataBase

# %%
connection.execute('commit')

# %%
connection.execute('CREATE DATABASE songs_db')
# Out:
# ---------------------------------------------------------------------------
# DuplicateDatabase                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# DuplicateDatabase: database "songs_db" already exists
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-28-1ee86219a902> in <module>
# ----> 1 connection.execute('CREATE DATABASE songs_db')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1004         """
#    1005         if isinstance(object_, util.string_types[0]):
# -> 1006             return self._execute_text(object_, multiparams, params)
#    1007         try:
#    1008             meth = object_._execute_on_connection
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1173         dialect = self.dialect
#    1174         parameters = _distill_params(multiparams, params)
# -> 1175         ret = self._execute_context(
#    1176             dialect,
#    1177             dialect.execution_ctx_cls._init_statement,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.DuplicateDatabase) database "songs_db" already exists
#
# [SQL: CREATE DATABASE songs_db]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
## Load CSV converted DataFrame into database

# %%
music_df.to_sql(name='spotify_songs', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from spotify_songs', con=engine).head()
# Out:
#    Decade  Year                                        Artist  \
# 0    1940  1940              Various Artists, Igor Stravinsky
# 1    1970  1977                                     Fela Kuti
# 2    1950  1956          D. Brubeck, The Dave Brubeck Quartet
# 3    1940  1949  André Gide, Jean Amrouche, Arthur Rubinstein
# 4    1960  1969                                   Miles Davis
#
#                                                 Song  \
# 0  A propos of Le Sacre - Commentary by Igor Stra...
# 1                                    Opposite People
# 2                                         Elementals
# 3                                             "Saül"
# 4                       Mademoiselle Mabry - New Mix
#
#                                                Genre  Duration_ms  \
# 0                                               None       999827
# 1               afrobeat, afropop, funk, soul, world       998280
# 2                                               None       997427
# 3                                               None       996000
# 4  bebop, contemporary post-bop, cool jazz, hard ...       993733
#
#                                           ArtistSong  Valence  Acousticness  \
# 0  Various Artists, Igor Stravinsky - A propos of...    0.405         0.350
# 1                        Fela Kuti - Opposite People    0.904         0.110
# 2  D. Brubeck, The Dave Brubeck Quartet - Elementals    0.273         0.804
# 3  André Gide, Jean Amrouche, Arthur Rubinstein -...    0.399         0.944
# 4         Miles Davis - Mademoiselle Mabry - New Mix    0.155         0.879
#
#    Danceability  ...  Explicit  Instrumentalness  Key  Liveness  Loudness  \
# 0         0.635  ...         0            0.0000    1    0.3830   -30.467
# 1         0.668  ...         0            0.0543    5    0.1230    -5.167
# 2         0.255  ...         0            0.0266    9    0.0947   -11.226
# 3         0.565  ...         0            0.0000   10    0.2140   -23.942
# 4         0.561  ...         0            0.7950    5    0.0995   -16.234
#
#    Mode  Popularity  Speechiness    Tempo                      ID
# 0     0           0       0.9300   85.650  431ryeJJoLFxBX1iSJFMde
# 1     0          25       0.1770  117.973  2nsQdjrZesTsFqVpYNBpUm
# 2     0           4       0.0420   78.110  2ieGcEuaTNlp6XQ1hzNtUA
# 3     1           0       0.9080   60.708  3F5BU0Uu6udC41I7jp3Wuu
# 4     0          22       0.0425  111.844  3OvO7qmeDemKrjGo7I542f
#
# [5 rows x 21 columns]
